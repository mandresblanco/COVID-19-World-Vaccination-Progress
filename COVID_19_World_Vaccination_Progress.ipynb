# %% [markdown]
# <a href="https://colab.research.google.com/github/mandresblanco/COVID-19-World-Vaccination-Progress/blob/main/COVID_19_World_Vaccination_Progress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/Projects'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/Projects
# country_profile_variables.csv		  country_vaccinations.csv
# country_vaccinations_by_manufacturer.csv  kiva_country_profile_variables.csv

# %%
df_c_profile = pd.read_csv('country_profile_variables.csv')
# df_c_profile['country'].unique().shape
# df_c_profile.dtypes

# %%
df_camerica = df_c_profile[df_c_profile['country'].isin(['Argentina', 'Bahamas', 'Barbados', 'Belize', 'Bolivia (Plurinational State of)', 
                                                           'Brazil', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 
                                                           'Cuba', 'Dominica', 'Ecuador', 'El Salvador', 'United States of America', 
                                                           'Grenada', 'Guatemala', 'Guyana', 'Haiti', 'Honduras', 
                                                           'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 
                                                          'Peru', 'Dominican Republic', 'Saint Kitts and Nevis', 'Saint Vincent and the Grenadines', 'Saint Lucia', 
                                                          'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela (Bolivarian Republic of)'])]
df_camerica
# Out:
#                                 country  ... Net Official Development Assist. received (% of GNI)
# 8                             Argentina  ...                                                -99
# 14                              Bahamas  ...                                                -99
# 17                             Barbados  ...                                                -99
# 20                               Belize  ...                                                -99
# 24     Bolivia (Plurinational State of)  ...                                                -99
# 28                               Brazil  ...                                                -99
# 37                               Canada  ...                                                -99
# 42                                Chile  ...                                                -99
# 46                             Colombia  ...                                                -99
# ...

# %%
df_camerica.columns
cols = ['country', 'Region',
       'Population in thousands (2017)', 
       'GDP: Gross domestic product (million current US$)',
       'Urban population (% of total population)',
       'Education: Government expenditure (% of GDP)']
cols
# Out:
# ['country',
#  'Region',
#  'Population in thousands (2017)',
#  'GDP: Gross domestic product (million current US$)',
#  'Urban population (% of total population)',
#  'Education: Government expenditure (% of GDP)']

# %%
df_america = df_camerica.loc[:,cols]
df_america
# Out:
#                                 country  ... Education: Government expenditure (% of GDP)
# 8                             Argentina  ...                                          5.3
# 14                              Bahamas  ...                                          ...
# 17                             Barbados  ...                                          6.6
# 20                               Belize  ...                                          6.4
# 24     Bolivia (Plurinational State of)  ...                                          7.3
# 28                               Brazil  ...                                          6.0
# 37                               Canada  ...                                          5.3
# 42                                Chile  ...                                          4.9
# 46                             Colombia  ...                                          4.5
# ...

# %%
df_america['Population in thousands (2017)'] = df_america['Population in thousands (2017)'] *1000
df_america['GDP: Gross domestic product (million current US$)'] = df_america['GDP: Gross domestic product (million current US$)'] *1000000

df_america
# Out:
#                                 country  ... Education: Government expenditure (% of GDP)
# 8                             Argentina  ...                                          5.3
# 14                              Bahamas  ...                                          ...
# 17                             Barbados  ...                                          6.6
# 20                               Belize  ...                                          6.4
# 24     Bolivia (Plurinational State of)  ...                                          7.3
# 28                               Brazil  ...                                          6.0
# 37                               Canada  ...                                          5.3
# 42                                Chile  ...                                          4.9
# 46                             Colombia  ...                                          4.5
# ...

# %%
df_america = df_america[['country', 'Region', 'Population in thousands (2017)',
 'GDP: Gross domestic product (million current US$)',
 'Urban population (% of total population)',
 'Education: Government expenditure (% of GDP)']].rename(columns={'Population in thousands (2017)': 'Population',
                                                                  'GDP: Gross domestic product (million current US$)': 'GDP',
                                                                   'Urban population (% of total population)': 'Urban_population',
                                                                    'Education: Government expenditure (% of GDP)': 'Education'
                                                                  })

# %%
# df_america.reset_index()
df_america = df_america.reset_index()
df_america=df_america.drop('index', axis=1)
df_america
# Out:
#                              country  ... Education
# 0                          Argentina  ...       5.3
# 1                            Bahamas  ...       ...
# 2                           Barbados  ...       6.6
# 3                             Belize  ...       6.4
# 4                            Bolivia  ...       7.3
# 5                             Brazil  ...       6.0
# 6                             Canada  ...       5.3
# 7                              Chile  ...       4.9
# 8                           Colombia  ...       4.5
# 9                         Costa Rica  ...       7.2
# 10                              Cuba  ...       ...
# 11                          Dominica  ...       -99
# 12                Dominican Republic  ...       ...
# 13                           Ecuador  ...       5.0
# 14                       El Salvador  ...       3.5
# 15                           Grenada  ...       ...
# 16                         Guatemala  ...       3.0
# ...

# %%
df_america.loc[33,'country'] = 'Venezuela'
df_america.loc[4,'country'] = 'Bolivia'
df_america.loc[31,'country'] = 'United States'
# df_america['Country'].unique() 
df_america
# Out:
#                              country  ... Education: Government expenditure (% of GDP)
# 0                          Argentina  ...                                          5.3
# 1                            Bahamas  ...                                          ...
# 2                           Barbados  ...                                          6.6
# 3                             Belize  ...                                          6.4
# 4                            Bolivia  ...                                          7.3
# 5                             Brazil  ...                                          6.0
# 6                             Canada  ...                                          5.3
# 7                              Chile  ...                                          4.9
# 8                           Colombia  ...                                          4.5
# 9                         Costa Rica  ...                                          7.2
# ...

# %%
df_vaccination = pd.read_csv('country_vaccinations.csv')
# df_vaccination.head(50)

# %%
df_vamerica = df_vaccination[df_vaccination['country'].isin(['Argentina', 'Bahamas', 'Barbados', 'Belize', 'Bolivia', 
                                                           'Brazil', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 
                                                           'Cuba', 'Dominica', 'Ecuador', 'El Salvador', 'United States', 
                                                           'Grenada', 'Guatemala', 'Guyana', 'Haiti', 'Honduras', 
                                                           'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 
                                                          'Peru', 'Dominican Republic', 'Saint Kitts and Nevis', 'Saint Vincent and the Grenadines', 'Saint Lucia', 
                                                          'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela'])]
df_vamerica['country'].unique()
# Out:
# array(['Argentina', 'Bahamas', 'Barbados', 'Belize', 'Bolivia', 'Brazil',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Grenada',
#        'Guatemala', 'Guyana', 'Honduras', 'Jamaica', 'Mexico',
#        'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Vincent and the Grenadines', 'Suriname',
#        'Trinidad and Tobago', 'United States', 'Uruguay', 'Venezuela'],
#       dtype=object)

# %%
df_vaccination.shape
df_vaccination
# Out:
#            country  ...                                     source_website
# 0      Afghanistan  ...                           https://covid19.who.int/
# 1      Afghanistan  ...                           https://covid19.who.int/
# 2      Afghanistan  ...                           https://covid19.who.int/
# 3      Afghanistan  ...                           https://covid19.who.int/
# 4      Afghanistan  ...                           https://covid19.who.int/
# ...            ...  ...                                                ...
# 18759     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1394757158...
# 18760     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1394757158...
# 18761     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1394757158...
# 18762     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1394757158...
# 18763     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1394757158...
#
# [18764 rows x 15 columns]

# %%
df_vamerica.head(141)
df_vamerica.head(41)
df_vamerica = df_vamerica.reset_index()
df_vamerica = df_vamerica.drop('index', axis=1)
df_vamerica
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 3104  Venezuela  ...  https://www.swissinfo.ch/spa/coronavirus-venez...
# 3105  Venezuela  ...  https://www.swissinfo.ch/spa/coronavirus-venez...
# 3106  Venezuela  ...  https://www.swissinfo.ch/spa/coronavirus-venez...
# 3107  Venezuela  ...  https://www.swissinfo.ch/spa/coronavirus-venez...
# 3108  Venezuela  ...  https://www.swissinfo.ch/spa/coronavirus-venez...
#
# [3109 rows x 15 columns]

# %%
df_vamerica.dtypes
df_vamerica['date'] = pd.to_datetime(df_vamerica['date'])

# %%
df_vamerica.dtypes
df_vamerica['date'].max()
# Out:
# Timestamp('2021-05-18 00:00:00')

# %%
# df_vamerica.columns
cols = ['country', 'date', 'total_vaccinations',
       'vaccines']
cols
# Out:
# ['country', 'date', 'total_vaccinations', 'vaccines']

# %%
# df_v_america = df_vamerica.loc[:,cols]
df_v_america
# Out:
#         country  ...                                          vaccines
# 0     Argentina  ...  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 1     Argentina  ...  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 2     Argentina  ...  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 3     Argentina  ...  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 4     Argentina  ...  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# ...         ...  ...                                               ...
# 3104  Venezuela  ...                                         Sputnik V
# 3105  Venezuela  ...                                         Sputnik V
# 3106  Venezuela  ...                                         Sputnik V
# 3107  Venezuela  ...                                         Sputnik V
# 3108  Venezuela  ...                                         Sputnik V
#
# [3109 rows x 4 columns]

# %%
dfdf = df_v_america.groupby(['country', 'total_vaccinations', 'vaccines'])['date'].max().reset_index()
df_t_america = dfdf.groupby(['country', 'vaccines'])['total_vaccinations'].max().reset_index()
df_t_america
# df_t_america['vaccines'].unique()
# Out:
#                              country  ... total_vaccinations
# 0                          Argentina  ...         10193368.0
# 1                            Bahamas  ...            36000.0
# 2                           Barbados  ...           121288.0
# 3                             Belize  ...            53496.0
# 4                            Bolivia  ...          1194572.0
# 5                             Brazil  ...         54332240.0
# 6                             Canada  ...         19088798.0
# 7                              Chile  ...         16735397.0
# 8                           Colombia  ...          7537763.0
# 9                         Costa Rica  ...          1251900.0
# 10                              Cuba  ...            70000.0
# 11                          Dominica  ...            33037.0
# 12                Dominican Republic  ...          3119820.0
# 13                           Ecuador  ...          1560453.0
# ...

# %%
# df_america = df_america[['country']].rename(columns={'Country':'country'})

df_merge = pd.merge(df_t_america[['country', 'total_vaccinations',	'vaccines']],
                    df_america, on = ['country'], how = 'inner')
df_merge 
# df_america
# Out:
#                              country  ...  Education
# 0                          Argentina  ...        5.3
# 1                            Bahamas  ...        ...
# 2                           Barbados  ...        6.6
# 3                             Belize  ...        6.4
# 4                            Bolivia  ...        7.3
# 5                             Brazil  ...        6.0
# 6                             Canada  ...        5.3
# 7                              Chile  ...        4.9
# 8                           Colombia  ...        4.5
# 9                         Costa Rica  ...        7.2
# 10                              Cuba  ...        ...
# 11                          Dominica  ...        -99
# 12                Dominican Republic  ...        ...
# 13                           Ecuador  ...        5.0
# 14                       El Salvador  ...        3.5
# 15                           Grenada  ...        ...
# 16                         Guatemala  ...        3.0
# ...

# %%
dir_pandas='/content/drive/My Drive/Colab Notebooks/Projects/{}'
dir_pandas
df_merge.to_csv(dir_pandas.format('vaccines.csv'))
